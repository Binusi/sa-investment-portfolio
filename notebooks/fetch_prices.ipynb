# %%
import yfinance as yf
import pandas as pd
from pathlib import Path

# %%
# Define the companies that we want to analyse
symbols = ["NPN.JO", "AGL.JO", "JSE.JO"]  # Naspers, Anglo American, JSE Ltd

# %%
df = yf.download(" ".join(symbols), start="2015-01-01", auto_adjust=True)
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
df
# Out:
# Price              Close                                       High  \
# Ticker            AGL.JO        JSE.JO         NPN.JO        AGL.JO
# Date
# 2015-01-01  20992.525391  12028.530273   95164.421875  20992.525391
# 2015-01-02  20833.619141  12001.690430   96050.054688  21447.806332
# 2015-01-05  19741.732422  11992.742188   95024.359375  21037.374297
# 2015-01-06  20140.468750  12028.530273   99806.695312  20181.414699
# 2015-01-07  20040.052734  12007.655273  103636.242188  20275.003727
# ...                  ...           ...            ...           ...
# 2025-08-26  52710.000000  12815.000000  591332.000000  53134.000000
# 2025-08-27  52660.000000  12835.000000  579489.000000  53379.000000
# 2025-08-28  54075.000000  12800.000000  578260.000000  54450.000000
# 2025-08-29  54250.000000  12668.000000  580867.000000  55000.000000
# 2025-09-01  53705.000000  12671.000000  573018.000000  54217.000000
#
# Price                                             Low                \
# ...

# %%
df.to_parquet("/Users/user1/coding-projects/sa-investments/sa-investment-portfolio/data/processed/jse_sample.parquet")
df.tail()
# Out:
# Price         Close                        High                         Low  \
# Ticker       AGL.JO   JSE.JO    NPN.JO   AGL.JO   JSE.JO    NPN.JO   AGL.JO
# Date
# 2025-08-26  52710.0  12815.0  591332.0  53134.0  12934.0  592739.0  51873.0
# 2025-08-27  52660.0  12835.0  579489.0  53379.0  12949.0  586400.0  52574.0
# 2025-08-28  54075.0  12800.0  578260.0  54450.0  12960.0  582990.0  52713.0
# 2025-08-29  54250.0  12668.0  580867.0  55000.0  12806.0  583955.0  53880.0
# 2025-09-01  53705.0  12671.0  573018.0  54217.0  12767.0  588263.0  53548.0
#
# Price                             Open                      Volume          \
# Ticker       JSE.JO    NPN.JO   AGL.JO   JSE.JO    NPN.JO   AGL.JO  JSE.JO
# Date
# 2025-08-26  12767.0  585012.0  52160.0  12901.0  588466.0  1315525  154722
# 2025-08-27  12701.0  576358.0  52697.0  12800.0  586400.0   900137   43613
# 2025-08-28  12800.0  576027.0  52570.0  12849.0  580620.0  1719179  195817
# ...
